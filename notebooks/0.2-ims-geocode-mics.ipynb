# %%
import os
import re
import json
import time
import requests
import pandas as pd
from glob import glob
from tqdm import tqdm
from joblib import Parallel, delayed
from pathlib import Path
from unidecode import unidecode
from dotenv import load_dotenv, find_dotenv
from collections import defaultdict, ChainMap

load_dotenv(find_dotenv())
API_KEY = os.environ.get('GMAPS_KEY', '')
PARENTHESES_PATTERN = re.compile(r'\ ?\(.*\)')

# %%
def _geocode(search_string):
    payload = {'key': API_KEY, 'address': search_string}
    r = requests.get('https://maps.googleapis.com/maps/api/geocode/json', params=payload)
    if r.status_code == 200:
        return r.json()
    else:
        print("Problem: ", search_string)
        return {}

def geocode_from_tuple(tup):
    country, admin1 = tup
    search_country = PARENTHESES_PATTERN.sub('', country)
    search_string = ', '.join((admin1, search_country))
    res = _geocode(search_string)
    res['_meta'] = {'key': tup, 'search_string': search_string}
    return res

# %%
childrens_surveys = {}
for f in Path("../data/interim/MICS").iterdir():
    if f.name.startswith('.'):
        continue
    elif not f.is_dir():
        continue
    childrens_surveys[f.stem] = pd.read_csv(f/'ch.csv', index_col=0, low_memory=False)

# %%
to_geocode = [(country, admin1) for country, cdf in childrens_surveys.items() for admin1 in cdf.HH7.unique()]
r = Parallel(n_jobs=4, verbose=5)(delayed(geocode_from_tuple)(tup) for tup in to_geocode)
# Out:
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 281 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=4)]: Done 322 out of 322 | elapsed:   20.3s finished

# %%
[d['_meta']['key'] for d in r if not d['results']]
# Out:
# [('Sao Tome and Principe', 'RegiÃ£o Centro Este'),
#  ('Sao Tome and Principe', 'RegiÃ£o Sul Este'),
#  ('Sao Tome and Principe', 'RegiÃ£o Norte Oeste'),
#  ('Pakistan (Punjab)', 'B. Nagar'),
#  ('Pakistan (Punjab)', 'M. Bahaudin'),
#  ('Dominican Republic', 'Cibao Nordeste'),
#  ('Viet Nam', 'Northern Midlands and Mountain area'),
#  ('Sudan', 'West Kordofan'),
#  ('Nepal', 'Eastern Terai'),
#  ('Nepal', 'Western  Terai'),
#  ('Nepal', 'Far-WesternTerai'),
#  ('Guinea Bissau', 'SAB')]

# %%
lookups = defaultdict(dict)
for result in r:
    country, admin1 = result['_meta']['key']
    lookups[country][admin1] = result
with open(Path('../data/interim/MICS/geocodes.json'), 'w') as f:
    json.dump(lookups, f, indent=2, sort_keys=True)

# %%
lookups['Pakistan (Punjab)']['M. Garh']
# Out:
# {'_meta': {'key': ('Pakistan (Punjab)', 'M. Garh'),
#   'search_string': 'M. Garh, Pakistan'},
#  'results': [{'address_components': [{'long_name': 'Muzaffargarh',
#      'short_name': 'Muzaffargarh',
#      'types': ['locality', 'political']},
#     {'long_name': 'Muzaffargarh',
#      'short_name': 'Muzaffargarh',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Punjab',
#      'short_name': 'Punjab',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Pakistan',
#      'short_name': 'PK',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Muzaffargarh, Pakistan',
#    'geometry': {'bounds': {'northeast': {'lat': 30.1144161, 'lng': 71.2265209},
#      'southwest': {'lat': 30.0286753, 'lng': 71.15027549999999}},
#     'location': {'lat': 30.07360869999999, 'lng': 71.1804988},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 30.1144161, 'lng': 71.2265209},
#      'southwest': {'lat': 30.0286753, 'lng': 71.15027549999999}}},
#    'place_id': 'ChIJFfokmf_XOjkRKhoRC085PB0',
#    'types': ['locality', 'political']}],
#  'status': 'OK'}

# %%
def pluck(result):
    d = {}
    try:
        loc = result['results'][0]
        d['place_id'] = loc.get('place_id')
        country_dict = [c for c in loc['address_components'] if 'country' in c['types']][0]
        if country_dict:
            d['country'] = country_dict.get('long_name')
            d['alpha2'] = country_dict.get('short_name')
        admin1_dict = [c for c in loc['address_components'] if 'administrative_area_level_1' in c['types']][0]
        if admin1_dict:
            d['admin1'] = admin1_dict.get('long_name')
        admin2_dict = [c for c in loc['address_components'] if 'administrative_area_level_2' in c['types']][0]
        if admin2_dict:
            d['admin2'] = admin2_dict.get('long_name')
        return d
    except (IndexError, KeyError):
        pass
    return d

# %%
pluck(lookups['Pakistan (Punjab)']['M. Garh'])
# Out:
# {'admin1': 'Punjab',
#  'admin2': 'Muzaffargarh',
#  'alpha2': 'PK',
#  'country': 'Pakistan',
#  'place_id': 'ChIJFfokmf_XOjkRKhoRC085PB0'}

# %%
pd.DataFrame.from_records([ChainMap({'c': d['_meta']['key'][0], 'hh7': d['_meta']['key'][1]}, pluck(d)) for d in r])
# Out:
#                               admin1                   admin2 alpha2  \
# 0                           Principe                      NaN     ST
# 1                                NaN                      NaN    NaN
# 2                                NaN                      NaN    NaN
# 3                                NaN                      NaN    NaN
# 4                           Ashgabat                      NaN     TM
# 5                               Ahal                      NaN     TM
# 6                             Balkan                      NaN     TM
# 7                  Dashoguz Province                      NaN     TM
# 8                              Lebap                      NaN     TM
# 9                               Mary                      NaN     TM
# 10                            Punjab               Bahawalpur     PK
# 11                               NaN                      NaN    NaN
# 12                            Punjab           Rahim Yar Khan     PK
# 13                            Punjab          Dera Ghazi Khan     PK
# 14                            Punjab                   Layyah     PK
# 15                            Punjab             Muzaffargarh     PK
# 16                            Punjab                 Rajanpur     PK
# 17                            Punjab               Faisalabad     PK
# 18                            Punjab                    Jhang     PK
# 19                            Punjab                    Jhang     PK
# 20                            Punjab  Toba Tek Singh District     PK
# 21                            Punjab               Gujranwala     PK
# 22                            Punjab                   Gujrat     PK
# 23                            Punjab                Hafizabad     PK
# 24                               NaN                      NaN    NaN
# 25                            Punjab                  Narowal     PK
# 26                            Punjab                  Sialkot     PK
# 27                            Punjab                   Lahore     PK
# 28                            Punjab                    Kasur     PK
# 29                            Punjab            Nankana Sahib     PK
# ..                               ...                      ...    ...
# 292                   Tombali Region                      NaN     GW
# 293                          Quinara                      NaN     GW
# 294                              Oio                      NaN     GW
# 295                           Biombo                      NaN     GW
# 296                           Bolama                      NaN     GW
# 297                           Bafata                   Bafata     GW
# 298                             Gabu                      NaN     GW
# 299                           Cacheu                   Cacheu     GW
# 300                              NaN                      NaN    NaN
# 301                   Bungoma County                      NaN     KE
# 302                           Oaxaca                      NaN     MX
# 303                  Baja California                      NaN     MX
# 304              Baja California Sur                      NaN     MX
# 305                      Mexico City                      NaN     MX
# 306                      Mexico City                      NaN     MX
# 307                              NaN                      NaN     MN
# 308                        Arkhangai                  Chuluut     MN
# 309                              Tov                      NaN     MN
# 310                           Dornod                      NaN     MN
# 311                      Ulaanbaatar                 Khan-Uul     MN
# 312                     Barima-Waini                      NaN     GY
# 313                Pomeroon-Supenaam                      NaN     GY
# 314  Essequibo Islands-West Demerara                      NaN     GY
# 315                 Demerara-Mahaica                      NaN     GY
# 316                  Mahaica-Berbice                      NaN     GY
# 317           East Berbice-Corentyne                      NaN     GY
# 318                  Cuyuni-Mazaruni                      NaN     GY
# 319                  Potaro-Siparuni                      NaN     GY
# 320     Upper Takutu-Upper Essequibo                      NaN     GY
# 321           Upper Demerara-Berbice                      NaN     GY
#
#                           c                country  \
# 0     Sao Tome and Principe  São Tomé and Príncipe
# 1     Sao Tome and Principe                    NaN
# 2     Sao Tome and Principe                    NaN
# 3     Sao Tome and Principe                    NaN
# 4              Turkmenistan           Turkmenistan
# 5              Turkmenistan           Turkmenistan
# 6              Turkmenistan           Turkmenistan
# 7              Turkmenistan           Turkmenistan
# 8              Turkmenistan           Turkmenistan
# 9              Turkmenistan           Turkmenistan
# 10        Pakistan (Punjab)               Pakistan
# 11        Pakistan (Punjab)                    NaN
# 12        Pakistan (Punjab)               Pakistan
# 13        Pakistan (Punjab)               Pakistan
# 14        Pakistan (Punjab)               Pakistan
# 15        Pakistan (Punjab)               Pakistan
# 16        Pakistan (Punjab)               Pakistan
# 17        Pakistan (Punjab)               Pakistan
# 18        Pakistan (Punjab)               Pakistan
# 19        Pakistan (Punjab)               Pakistan
# 20        Pakistan (Punjab)               Pakistan
# 21        Pakistan (Punjab)               Pakistan
# 22        Pakistan (Punjab)               Pakistan
# 23        Pakistan (Punjab)               Pakistan
# 24        Pakistan (Punjab)                    NaN
# 25        Pakistan (Punjab)               Pakistan
# 26        Pakistan (Punjab)               Pakistan
# 27        Pakistan (Punjab)               Pakistan
# 28        Pakistan (Punjab)               Pakistan
# 29        Pakistan (Punjab)               Pakistan
# ..                      ...                    ...
# 292           Guinea Bissau          Guinea-Bissau
# 293           Guinea Bissau          Guinea-Bissau
# 294           Guinea Bissau          Guinea-Bissau
# 295           Guinea Bissau          Guinea-Bissau
# 296           Guinea Bissau          Guinea-Bissau
# 297           Guinea Bissau          Guinea-Bissau
# 298           Guinea Bissau          Guinea-Bissau
# 299           Guinea Bissau          Guinea-Bissau
# 300           Guinea Bissau                    NaN
# 301  Kenya (Bungoma County)                  Kenya
# 302                  Mexico                 Mexico
# 303                  Mexico                 Mexico
# 304                  Mexico                 Mexico
# 305                  Mexico                 Mexico
# 306                  Mexico                 Mexico
# 307                Mongolia               Mongolia
# 308                Mongolia               Mongolia
# 309                Mongolia               Mongolia
# 310                Mongolia               Mongolia
# 311                Mongolia               Mongolia
# 312                  Guyana                 Guyana
# 313                  Guyana                 Guyana
# 314                  Guyana                 Guyana
# 315                  Guyana                 Guyana
# 316                  Guyana                 Guyana
# 317                  Guyana                 Guyana
# 318                  Guyana                 Guyana
# 319                  Guyana                 Guyana
# 320                  Guyana                 Guyana
# 321                  Guyana                 Guyana
#
#                                  hh7                     place_id
# 0       RegiÃ£o Autonoma de Principe  ChIJYRBve0mNcBAR-ejxSaiODH4
# 1                RegiÃ£o Centro Este                          NaN
# 2                   RegiÃ£o Sul Este                          NaN
# 3                RegiÃ£o Norte Oeste                          NaN
# 4                      Ashgabat city  ChIJ2YQ2qxv-bz8R6a3TYj8B3jw
# 5                       Ahal velayat  ChIJEX3vZloKZT8RLueEJqTQ7pU
# 6                     Balkan velayat  ChIJaeolWIv_KkARdJtx7a_WlxM
# 7                   Dashoguz velayat  ChIJeSEwf20D2UERbIbWneItyOE
# 8                      Lebap velayat  ChIJ-z2ejiPgRD8R8ynVfO4H4gs
# 9                       Mary velayat  ChIJt4hgKiSOQT8Rw5qCF8eRX5Q
# 10                        Bahawalpur  ChIJ1RphbMSQOzkRYvgD4agN3_w
# 11                          B. Nagar                          NaN
# 12                           RY Khan  ChIJOdtFO3FcNzkRcAEqZ8Ejryg
# 13                           DG Khan  ChIJdWX_LOmxOjkRu68h-bT4nhw
# 14                            Layyah  ChIJW8nU1eKmJTkRADtn5WGq_0g
# 15                           M. Garh  ChIJFfokmf_XOjkRKhoRC085PB0
# 16                          Rajanpur  ChIJ01L7bjmZMDkR9DAkk3pzk5Y
# 17                        Faisalabad  ChIJqVyllahCIjkRxnEmk4iPxd4
# 18                           Chiniot  ChIJs6vuhkM7IjkRi31giSiIx_M
# 19                             Jhang  ChIJw8s4saGiIzkRoRGSJbnB1N4
# 20                          TT Singh  ChIJT-rtPM0PIzkRWlLDbfxpHP4
# 21                        Gujranwala  ChIJKesg1YMpHzkRaKPnha8z-wY
# 22                            Gujrat  ChIJLURDHgMbHzkRTGg9VCP9cAg
# 23                         Hafizabad  ChIJLeHfbLtNHzkRVYuvFFfQec0
# 24                       M. Bahaudin                          NaN
# 25                           Narowal  ChIJ7ZmMdIZTGTkRR80au0FU-lg
# 26                           Sialkot  ChIJ_WzbdFbqHjkRREdtlIM50Kg
# 27                            Lahore  ChIJ2QeB5YMEGTkRYiR-zGy-OsI
# 28                             Kasur  ChIJzaBTZXu5GTkR0o6qZB-ABpM
# 29                          N. Sahib  ChIJuepB90yOGDkRN1xI0J1ZBOM
# ..                               ...                          ...
# 292                          Tombali  ChIJz92ag4de4Q4RdlFg-wScQ8U
# 293                          Quinara  ChIJdeCc_RlK4Q4R9WFFJXjvAFg
# 294                              Oio  ChIJqwI52dFk5g4R7FierB54Chc
# 295                           Biombo  ChIJ09Et2K3d5g4RDlV2uD2gYmU
# 296                   Bolama/Bijagós  ChIJSzDEv0_c4A4R3xQEXnZ_8Qs
# 297                           Bafatá  ChIJxzEM9ZI45A4Ribk-wjRn5L0
# 298                             Gabú  ChIJn-6bOIDt5A4Rwxvi1HRLeH8
# 299                           Cacheu  ChIJ6UX4YNZ05w4R2FdXdMMZ_5I
# 300                              SAB                          NaN
# 301                          Bungoma  ChIJt7ffLYvWgRcRdSSKeFABuYI
# 302                          Noreste  ChIJ0XJIrY0mxoURPAbGIMumRBM
# 303                         Noroeste  ChIJAQAAFQJTn4YRdR4eplp0fY0
# 304                              Sur  ChIJyR6itTnTr4YRGFmnqTqz33E
# 305                           Centro  ChIJvU0OLi350YURPYnEQKd0VZA
# 306                    DF-Edo México  ChIJB3UJ2yYAzoURQeheJnYQBlQ
# 307                          Western  ChIJn5APznS0tEIRrOP9XOUUpUo
# 308                          Khangai  ChIJg1lz_TvQcF0RFYPUBMFsols
# 309                          Central  ChIJQWVhqf3qkF0RFY0Oz_5de7U
# 310                          Eastern  ChIJuYJP5wyLxF0RGfdJV9ZrkLs
# 311                      Ulaanbaatar  ChIJq4qx4luSll0Rf4ShZHiSBuY
# 312                     Barima-Waini  ChIJS4F8GAo2sY0R-SMH9mD9m-M
# 313                Pomeroon-Supenaam  ChIJh60FNPFLsI0RB-V0cg-s8jk
# 314  Essequibo Islands-West Demerara  ChIJOYEEs_4fsI0RVeYUbtxcZyI
# 315                 Demerara-Mahaica  ChIJK3nEAHJbpY0RYPqzfHKIIBI
# 316                  Mahaica-Berbice  ChIJLQsyGfcRpY0RT8-d7V6Lmgk
# 317           East Berbice-Corentyne  ChIJVWHamOmdmY0RH2XadDks9sM
# 318                  Cuyuni-Mazaruni  ChIJTwMjz22RuI0R0IpHKvri4Gc
# 319                  Potaro-Siparuni  ChIJp3PhObt9vI0RfUnJ51rT_tE
# 320     Upper Takutu-Upper Essequibo  ChIJN7OXmcLkkI0Rf6-oS350Rh8
# 321           Upper Demerara-Berbice  ChIJEa5w26hWo40RkLByztM0O9g
#
# [322 rows x 7 columns]
