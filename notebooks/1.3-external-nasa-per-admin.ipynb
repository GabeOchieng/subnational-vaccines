# %%
# %matplotlib inline

from pathlib import Path
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from unidecode import unidecode

DATA_EXT = (Path(os.getcwd()) / os.pardir / 'data' / 'external').resolve()

# %%
import sys
sys.path.append(os.path.join(os.getcwd(), os.pardir, 'src'))

# %load_ext autoreload

# %autoreload 2
from visualization.visualize import *
from data.geo_utils import canonicalize_dataframe_geographies

# %% [markdown]
# ### This notebook loads the raw NASA GPW v4.10 data and then writes the estimated population at the admin2 and country levels to `interim`

# %%
df = pd.read_csv(DATA_EXT/'nasa-gpw'/'gpw_v4_admin_unit_center_points_population_estimates_rev10_global.csv')
df.head()
# Out:
# /Users/bull/anaconda3/envs/subnational-vaccines/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                     GUBID ISOALPHA COUNTRYNM  \
# 0  {F1A487E2-8EA6-4934-AE6E-F3B7BF0A6DAE}      ABW     Aruba
# 1  {344FA064-8E7A-4884-A9F9-3824164F34AE}      ABW     Aruba
# 2  {0E49304A-B532-4842-9E47-540C5D5DFFBD}      ABW     Aruba
# 3  {89AD49DF-E7F8-43B0-A2F1-4CB018B87CA4}      ABW     Aruba
# 4  {DF116CBC-DDCD-4A53-9B8D-81C65DE10BE0}      ABW     Aruba
#
#                NAME1                    NAME2 NAME3 NAME4 NAME5 NAME6  \
# 0           Paradera              Piedra Plat   NaN   NaN   NaN   NaN
# 1  San Nicolas North               Rooi Congo   NaN   NaN   NaN   NaN
# 2  San Nicolas South           Seroe Colorado   NaN   NaN   NaN   NaN
# 3  San Nicolas South   Pastoor Hendriksstraat   NaN   NaN   NaN   NaN
# 4  San Nicolas South  San Nicolas South Other   NaN   NaN   NaN   NaN
#
#    CENTROID_X    ...        A60_64M    A65PLUSM    A65_69M   A70PLUSM  \
# 0  -69.991539    ...      57.419963  115.923321  52.002985  63.920336
# 1  -69.913123    ...      56.343235  121.354661  46.591522  74.763139
# 2  -69.877344    ...       4.329681   15.153885   4.329681  10.824204
# 3  -69.907521    ...      29.225350   73.604585  24.895669  48.708917
# 4  -69.901461    ...       0.000000    0.000000   0.000000   0.000000
#
#      A70_74M   A75PLUSM    A75_79M   A80PLUSM    A80_84M   A85PLUSM
# 0  30.335075  33.585261  19.501119  14.084142   7.583769   6.500373
# 1  36.839808  37.923332  20.586951  17.336380  13.002285   4.334095
# 2   5.412102   5.412102   4.329681   1.082420   0.000000   1.082420
# 3  12.989044  35.719872  11.906624  23.813248  10.824204  12.989044
# 4   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
# [5 rows x 98 columns]

# %%
admin_2_populations = df.groupby(['ISOALPHA', 'NAME1', 'NAME2']).UN_2015_E.sum()
admin_2_populations
# Out:
# ISOALPHA  NAME1                  NAME2
# ABW       Noord/ Tanki Leendert  Alto Vista                     5503.0
#                                  Moko/Tanki Flip                4071.0
#                                  Noord Other                       0.0
#                                  Palm Beach/Malmok              5499.0
#                                  Tanki Leendert                 3958.0
#                                  Washington                     4163.0
#           Oranjestad East        Dacota/Potrero                 2480.0
#                                  Klip/Mon Plaisir               1240.0
#                                  Nassaustraat                    714.0
#                                  Oranjestad East Other             0.0
#                                  Sabana Blanco/Mahuma           3000.0
#                                  Seroe Blanco/Cumana            2553.0
#                                  Simeon Antonio                 1001.0
#                                  Sividivi                        885.0
#                                  Tarabana                       1908.0
#           Oranjestad West        Companashi/Solito              2600.0
#                                  Eeagle/Paardenbaaistraat        429.0
#                                  Madiki Kavel                   2836.0
#                                  Madiki/Rancho                  1424.0
#                                  Paradijswijk/Santa Helena      2019.0
#                                  Ponton                         2109.0
#                                  Pos Abao/Cunucu Abao           1268.0
#                                  Socotoro/Rancho                1805.0
#           Paradera               Ayo                            3676.0
#                                  Paradera                       2522.0
#                                  Paradera other                    0.0
#                                  Piedra Plat                    2514.0
#                                  Shiribana                      4727.0
#           San Nicolas North      Brasil                         2505.0
#                                  Juana Morto                    1489.0
#                                                                 ...
# ZWE       Matabeleland North     Hwange Rural                  73562.0
#                                  Lupane                       117569.0
#                                  Nkayi                        128103.0
#                                  Tsholotsho                   135127.0
#                                  Umguza                       105275.0
#                                  Vic Falls                     39613.0
#           Matabeleland South     Beitbridge                    49266.0
#                                  Beitbridge Rural              93632.0
#                                  Bulilima                     105882.0
#                                  Gwanda                        23649.0
#                                  Gwanda Rural                 135366.0
#                                  Insiza                       117308.0
#                                  Mangwe                        77421.0
#                                  Matobo                       109833.0
#                                  Plumtree                      13593.0
#                                  Umzingwane                    73647.0
#           Midlands               Chirumhanzu                   95422.0
#                                  Gokwe North                  285433.0
#                                  Gokwe South                  363373.0
#                                  Gokwe Town                    28566.0
#                                  Gweru                        187474.0
#                                  Gweru Rural                  109025.0
#                                  Kwekwe                       119825.0
#                                  Kwekwe Rural                 207499.0
#                                  Mberengwa                    220598.0
#                                  Redcliff                      42668.0
#                                  Shurugwi                      26014.0
#                                  Shurugwi Rural                92119.0
#                                  Zvishavane                    86114.0
#                                  Zvishavane Mine               53713.0
# Name: UN_2015_E, Length: 42230, dtype: float64

# %%
country_populations = df.groupby(['ISOALPHA']).UN_2015_E.sum()

# %%
admin_2_populations.to_frame().to_csv(Path("../data/interim/external-processed/admin_population_nasa.csv"))

# %%
country_populations.to_frame().to_csv(Path("../data/interim/external-processed/counrty_population_nasa.csv"))

# %% [markdown]
# # Load immunization data
#
# immunization data is from WHO

# %%
who_df = pd.read_csv(Path('../data/interim/calc_cols_added.csv'), index_col=0)


denoms = who_df[['Iso Code', 'Admin1', 'Admin2', 'available_admin', 'Denominator']].drop_duplicates()

print(denoms.shape)
denoms.head()
# Out:
# (38259, 5)
#   Iso Code Admin1      Admin2 available_admin  Denominator
# 0      AFG    NaN    Aab Band        Aab Band       1266.0
# 1      AFG    NaN  Aab Kamari      Aab Kamari       4599.0
# 2      AFG    NaN      Aaqcha          Aaqcha       5674.0
# 3      AFG    NaN      Acheen          Acheen       4846.0
# 4      AFG    NaN    Adraskan        Adraskan       3557.0

# %%
print(admin_2_populations.shape)
admin_2_populations = admin_2_populations.to_frame()
admin_2_populations.reset_index(inplace=True)
admin_2_populations.head()
# Out:
# (42230,)
#   ISOALPHA                  NAME1              NAME2  UN_2015_E
# 0      ABW  Noord/ Tanki Leendert         Alto Vista     5503.0
# 1      ABW  Noord/ Tanki Leendert    Moko/Tanki Flip     4071.0
# 2      ABW  Noord/ Tanki Leendert        Noord Other        0.0
# 3      ABW  Noord/ Tanki Leendert  Palm Beach/Malmok     5499.0
# 4      ABW  Noord/ Tanki Leendert     Tanki Leendert     3958.0

# %%
def canonicalize_regions(x):
    x = unidecode(x.strip().lower())
    
    x = x.replace("-", " ")
    x = x.replace("/", " ")
    x = x.replace("-", " ")

    return x

admin_2_populations['admin2_clean'] = admin_2_populations.NAME2.apply(canonicalize_regions)
denoms['admin2_clean'] = denoms.available_admin.apply(canonicalize_regions)

# %%
admin_2_populations['join_index'] = admin_2_populations.ISOALPHA + "--" + admin_2_populations.admin2_clean
denoms['join_index'] = denoms['Iso Code'] + "--" + denoms.admin2_clean

# %%
admin_2_populations.set_index('join_index').join(denoms.set_index('join_index'), how='inner', rsuffix='_').shape
# Out:
# (571, 11)

# %%
admin_2_populations[admin_2_populations.ISOALPHA == 'AFG'].sort_values('join_index')
# Out:
#     ISOALPHA       NAME1                  NAME2  UN_2015_E  \
# 162      AFG      Ghazni                Ab Band    27597.0
# 83       AFG     Badghis              Ab Kamari    98428.0
# 325      AFG   Nangarhar                 Acheen   127203.0
# 204      AFG       Hirat               Adraskan    71013.0
# 380      AFG      Paktya             Ahmad Abad    34959.0
# 163      AFG      Ghazni               Ajristan    28962.0
# 262      AFG      Kapisa                 Alasay    46223.0
# 381      AFG      Paktya       Ali Khail (Jaji)    78822.0
# 297      AFG      Kunduz                Aliabad    53201.0
# 304      AFG     Laghman                Alingar   124303.0
# 305      AFG     Laghman               Alishing    91783.0
# 148      AFG      Faryab                  Almar    90022.0
# 137      AFG       Farah              Anar Dara    36136.0
# 164      AFG      Ghazni                  Andar   125081.0
# 90       AFG     Baghlan                Andarab    30926.0
# 149      AFG      Faryab                Andkhoy    50562.0
# 220      AFG     Jawzjan                  Aqcha    69674.0
# 445      AFG       Zabul              Arghandab    40008.0
# 246      AFG    Kandahar              Arghandab    78856.0
# 55       AFG  Badakhshan           Arghanj Khaw    21360.0
# 247      AFG    Kandahar              Arghistan    43883.0
# 56       AFG  Badakhshan                   Argo   103887.0
# 282      AFG       Kunar               Asadabad    42184.0
# 446      AFG       Zabul                 Atghar    10737.0
# 408      AFG    Samangan                  Aybak   127299.0
# 309      AFG       Logar                   Azra    25486.0
# 91       AFG     Baghlan         Baghlani Jadid   207988.0
# 191      AFG     Hilmand                Baghran    99949.0
# 398      AFG      Parwan                 Bagram   123237.0
# 231      AFG       Kabul                Bagrami    70304.0
# ..       ...         ...                    ...        ...
# 373      AFG     Paktika                  Urgun    67566.0
# 178      AFG      Ghazni                 Waghaz    38720.0
# 77       AFG  Badakhshan                 Wakhan    19834.0
# 179      AFG      Ghazni  Wali Muhammadi Shahid    20147.0
# 359      AFG    Nuristan                   Wama    13861.0
# 126      AFG      Bamyan                  Waras   136126.0
# 78       AFG  Badakhshan                 Warduj    28989.0
# 437      AFG      Takhar                 Warsaj    48356.0
# 203      AFG     Hilmand                 Washer    19093.0
# 296      AFG       Kunar               Wata Pur    34865.0
# 360      AFG    Nuristan                 Waygal    24584.0
# 374      AFG     Paktika              Waza Khwa    28281.0
# 375      AFG     Paktika               Wor Mayi     4351.0
# 79       AFG  Badakhshan           Yaftal Sufla    70044.0
# 376      AFG     Paktika             Yahya Khel    21242.0
# 127      AFG      Bamyan              Yakawlang   109110.0
# 80       AFG  Badakhshan        Yamgan (Girwan)    34120.0
# 438      AFG      Takhar             Yangi Qala    56482.0
# 81       AFG  Badakhshan                  Yawan    43136.0
# 377      AFG     Paktika             Yosuf Khel    16508.0
# 389      AFG      Paktya                 Zadran    44387.0
# 180      AFG      Ghazni              Zana Khan    12592.0
# 219      AFG       Hirat             Zanda  Jan    75434.0
# 352      AFG      Nimroz                 Zaranj    66605.0
# 378      AFG     Paktika          Zarghun Shahr    36470.0
# 120      AFG       Balkh                   Zari    51890.0
# 82       AFG  Badakhshan                  Zebak    10403.0
# 261      AFG    Kandahar                  Zhari   109042.0
# 379      AFG     Paktika                  Ziruk    23546.0
# 390      AFG      Paktya                 Zurmat   134600.0
#
#               admin2_clean                  join_index
# 162                ab band                AFG--ab band
# 83               ab kamari              AFG--ab kamari
# 325                 acheen                 AFG--acheen
# 204               adraskan               AFG--adraskan
# 380             ahmad abad             AFG--ahmad abad
# 163               ajristan               AFG--ajristan
# 262                 alasay                 AFG--alasay
# 381       ali khail (jaji)       AFG--ali khail (jaji)
# 297                aliabad                AFG--aliabad
# 304                alingar                AFG--alingar
# 305               alishing               AFG--alishing
# 148                  almar                  AFG--almar
# 137              anar dara              AFG--anar dara
# 164                  andar                  AFG--andar
# 90                 andarab                AFG--andarab
# 149                andkhoy                AFG--andkhoy
# 220                  aqcha                  AFG--aqcha
# 445              arghandab              AFG--arghandab
# 246              arghandab              AFG--arghandab
# 55            arghanj khaw           AFG--arghanj khaw
# 247              arghistan              AFG--arghistan
# 56                    argo                   AFG--argo
# 282               asadabad               AFG--asadabad
# 446                 atghar                 AFG--atghar
# 408                  aybak                  AFG--aybak
# 309                   azra                   AFG--azra
# 91          baghlani jadid         AFG--baghlani jadid
# 191                baghran                AFG--baghran
# 398                 bagram                 AFG--bagram
# 231                bagrami                AFG--bagrami
# ..                     ...                         ...
# 373                  urgun                  AFG--urgun
# 178                 waghaz                 AFG--waghaz
# 77                  wakhan                 AFG--wakhan
# 179  wali muhammadi shahid  AFG--wali muhammadi shahid
# 359                   wama                   AFG--wama
# 126                  waras                  AFG--waras
# 78                  warduj                 AFG--warduj
# 437                 warsaj                 AFG--warsaj
# 203                 washer                 AFG--washer
# 296               wata pur               AFG--wata pur
# 360                 waygal                 AFG--waygal
# 374              waza khwa              AFG--waza khwa
# 375               wor mayi               AFG--wor mayi
# 79            yaftal sufla           AFG--yaftal sufla
# 376             yahya khel             AFG--yahya khel
# 127              yakawlang              AFG--yakawlang
# 80         yamgan (girwan)        AFG--yamgan (girwan)
# 438             yangi qala             AFG--yangi qala
# 81                   yawan                  AFG--yawan
# 377             yosuf khel             AFG--yosuf khel
# 389                 zadran                 AFG--zadran
# 180              zana khan              AFG--zana khan
# 219             zanda  jan             AFG--zanda  jan
# 352                 zaranj                 AFG--zaranj
# 378          zarghun shahr          AFG--zarghun shahr
# 120                   zari                   AFG--zari
# 82                   zebak                  AFG--zebak
# 261                  zhari                  AFG--zhari
# 379                  ziruk                  AFG--ziruk
# 390                 zurmat                 AFG--zurmat
#
# [401 rows x 6 columns]

# %%
bad
# Out:
#         Iso Code Admin1                   Admin2          available_admin  \
# 20   Afghanistan    NaN         Asl-e-Chakhansor         Asl-e-Chakhansor
# 24   Afghanistan    NaN                     Baak                     Baak
# 31   Afghanistan    NaN              Bala Bolook              Bala Bolook
# 32   Afghanistan    NaN              Balcheraagh              Balcheraagh
# 43   Afghanistan    NaN                  Behsood                  Behsood
# 44   Afghanistan    NaN                    Borka                    Borka
# 57   Afghanistan    NaN                   Chawki                   Chawki
# 59   Afghanistan    NaN                 Chemtaal                 Chemtaal
# 67   Afghanistan    NaN              Dara-e-Noor              Dara-e-Noor
# 68   Afghanistan    NaN             Dara-e-Peach             Dara-e-Peach
# 79   Afghanistan    NaN             Day Meerdaad             Day Meerdaad
# 80   Afghanistan    NaN        Deela wa Khosmand        Deela wa Khosmand
# 81   Afghanistan    NaN                   Deesho                   Deesho
# 90   Afghanistan    NaN                   Enjeel                   Enjeel
# 93   Afghanistan    NaN                Eshtarlee                Eshtarlee
# 94   Afghanistan    NaN                  Esperah                  Esperah
# 103  Afghanistan    NaN                Garzewaan                Garzewaan
# 104  Afghanistan    NaN                   Geelan                   Geelan
# 105  Afghanistan    NaN                    Geero                    Geero
# 106  Afghanistan    NaN                    Geeti                    Geeti
# 121  Afghanistan    NaN  Guzarah (Nizam Shaheed)  Guzarah (Nizam Shaheed)
# 123  Afghanistan    NaN          Hazrat-e-Sultan          Hazrat-e-Sultan
# 127  Afghanistan    NaN     His-e-Awal-e-Behsood     His-e-Awal-e-Behsood
# 128  Afghanistan    NaN   His-e-Dwoom-e-Kohestan   His-e-Dwoom-e-Kohestan
# 130  Afghanistan    NaN           Jabal-us-Seraj           Jabal-us-Seraj
# 145  Afghanistan    NaN    Kakar (Khak-e-Afghan)    Kakar (Khak-e-Afghan)
# 146  Afghanistan    NaN                Kalafgaan                Kalafgaan
# 153  Afghanistan    NaN           Keran-o-Menjan           Keran-o-Menjan
# 154  Afghanistan    NaN               Keshen Deh               Keshen Deh
# 155  Afghanistan    NaN      Keshk (Robat Sangi)      Keshk (Robat Sangi)
# 156  Afghanistan    NaN            Keshk-e-Kohna            Keshk-e-Kohna
# 160  Afghanistan    NaN              Khaash Road              Khaash Road
# 179  Afghanistan    NaN            Khowaja Omary            Khowaja Omary
# 180  Afghanistan    NaN   Khowaja Sabz Posh Wali   Khowaja Sabz Posh Wali
# 191  Afghanistan    NaN           Laash-o-Jaween           Laash-o-Jaween
# 192  Afghanistan    NaN         Laja Ahmad Kheil         Laja Ahmad Kheil
# 193  Afghanistan    NaN            Laja Mangal *            Laja Mangal *
# 194  Afghanistan    NaN                 Lal Poor                 Lal Poor
#
#      Denominator             admin2_clean                    join_index
# 20        2135.0         asl e chakhansor         AFG--asl e chakhansor
# 24         615.0                     baak                     AFG--baak
# 31        3027.0              bala bolook              AFG--bala bolook
# 32        6308.0              balcheraagh              AFG--balcheraagh
# 43        5605.0                  behsood                  AFG--behsood
# 44        3121.0                    borka                    AFG--borka
# 57        1966.0                   chawki                   AFG--chawki
# 59        4552.0                 chemtaal                 AFG--chemtaal
# 67        2515.0              dara e noor              AFG--dara e noor
# 68        4219.0             dara e peach             AFG--dara e peach
# 79        2089.0             day meerdaad             AFG--day meerdaad
# 80         472.0        deela wa khosmand        AFG--deela wa khosmand
# 81        1407.0                   deesho                   AFG--deesho
# 90       12679.0                   enjeel                   AFG--enjeel
# 93        2899.0                eshtarlee                AFG--eshtarlee
# 94         956.0                  esperah                  AFG--esperah
# 103       2538.0                garzewaan                AFG--garzewaan
# 104       2778.0                   geelan                   AFG--geelan
# 105       1407.0                    geero                    AFG--geero
# 106       1661.0                    geeti                    AFG--geeti
# 121       7584.0  guzarah (nizam shaheed)  AFG--guzarah (nizam shaheed)
# 123       2158.0          hazrat e sultan          AFG--hazrat e sultan
# 127       3021.0     his e awal e behsood     AFG--his e awal e behsood
# 128       3143.0   his e dwoom e kohestan   AFG--his e dwoom e kohestan
# 130       1131.0           jabal us seraj           AFG--jabal us seraj
# 145       1373.0    kakar (khak e afghan)    AFG--kakar (khak e afghan)
# 146       1949.0                kalafgaan                AFG--kalafgaan
# 153        531.0           keran o menjan           AFG--keran o menjan
# 154       3893.0               keshen deh               AFG--keshen deh
# 155       2195.0      keshk (robat sangi)      AFG--keshk (robat sangi)
# 156       4570.0            keshk e kohna            AFG--keshk e kohna
# 160       1180.0              khaash road              AFG--khaash road
# 179       1941.0            khowaja omary            AFG--khowaja omary
# 180       2109.0   khowaja sabz posh wali   AFG--khowaja sabz posh wali
# 191       1676.0           laash o jaween           AFG--laash o jaween
# 192       1111.0         laja ahmad kheil         AFG--laja ahmad kheil
# 193       1111.0            laja mangal *            AFG--laja mangal *
# 194       1913.0                 lal poor                 AFG--lal poor

# %%
res = canonicalize_dataframe_geographies(denoms.head(200), 'Iso Code', 'Admin1', 'Admin2', return_failures=True)

if isinstance(res, tuple):
    good, bad = res
else:
    good = res

good
# Out:
#          admin1             admin2      country
# 0        Ghazni            Ab Band  Afghanistan
# 1       Badghis          Ab Kamari  Afghanistan
# 2       Jowzjan           Mingajik  Afghanistan
# 3     Nangarhar              Achin  Afghanistan
# 4         Herat           Adraskan  Afghanistan
# 5         Herat             Kohsan  Afghanistan
# 6        Ghazni           Ajristan  Afghanistan
# 7        Kapisa             Alasay  Afghanistan
# 8       Laghman            Alingar  Afghanistan
# 9        Kunduz        Chahar Dara  Afghanistan
# 10      Laghman           Alishing  Afghanistan
# 11       Faryab        Khwaja Sabz  Afghanistan
# 12        Farah          Anar Dara  Afghanistan
# 13       Ghazni              Andar  Afghanistan
# 14      Baghlan            Andarab  Afghanistan
# 15       Faryab  Khani Chahar Bagh  Afghanistan
# 16     Kandahar          Arghandab  Afghanistan
# 17     Kandahar          Arghandab  Afghanistan
# 18     Kandahar          Arghistan  Afghanistan
# 19        Kunar                     Afghanistan
# 20
# 21        Zabul             Atghar  Afghanistan
# 22     Samangan     Hazrati Sultan  Afghanistan
# 23       Paktia               Azra  Afghanistan
# 24
# 25      Baghlan     Baghlani Jadid  Afghanistan
# 26      Helmand            Baghran  Afghanistan
# 27       Parvan         Chaharikar  Afghanistan
# 28        Kabul              Kabul  Afghanistan
# 29   Badakhshan               Jurm  Afghanistan
# ..          ...                ...          ...
# 170   Nangarhar           Khogyani  Afghanistan
# 171       Balkh              Khulm  Afghanistan
# 172    Samangan  Khuram Wa Sarbagh  Afghanistan
# 173       Logar             Khushi  Afghanistan
# 174       Khost              Khost  Afghanistan
# 175       Khost              Khost  Afghanistan
# 176  Badakhshan            Khwahan  Afghanistan
# 177     Jowzjan      Khwaja Du Koh  Afghanistan
# 178      Takhar        Khwaja Ghar  Afghanistan
# 179
# 180
# 181      Kapisa           Koh Band  Afghanistan
# 182      Parvan          Kohi Safi  Afghanistan
# 183      Kapisa           Kohistan  Afghanistan
# 184      Kapisa           Kohistan  Afghanistan
# 185      Kapisa           Kohistan  Afghanistan
# 186     Bamiyan            Kahmard  Afghanistan
# 187       Herat             Kohsan  Afghanistan
# 188   Nangarhar          Kuz Kunar  Afghanistan
# 189   Nangarhar           Bati Kot  Afghanistan
# 190      Kunduz             Kunduz  Afghanistan
# 191
# 192
# 193
# 194
# 195        Ghor   Lal Wa Sarjangal  Afghanistan
# 196     Helmand        Lashkar Gah  Afghanistan
# 197       Balkh                     Afghanistan
# 198      Parvan        Jabul Saraj  Afghanistan
# 199      Wardak              Nirkh  Afghanistan
#
# [200 rows x 3 columns]

# %%
# !cat ../data/interim/geo_query_cache.json | jq .
# Out:
# {
#   "Aab Band  Afghanistan": {
#     "admin2": "Ab Band",
#     "admin1": "Ghazni",
#     "country": "Afghanistan"
#   },
#   "Aab Kamari  Afghanistan": {
#     "admin2": "Ab Kamari",
#     "admin1": "Badghis",
#     "country": "Afghanistan"
#   },
#   "Aaqcha  Afghanistan": {
#     "admin2": "Mingajik",
#     "admin1": "Jowzjan",
#     "country": "Afghanistan"
#   },
#   "Acheen  Afghanistan": {
#     "admin2": "Achin",
#     "admin1": "Nangarhar",
#     "country": "Afghanistan"
#   },
#   "Adraskan  Afghanistan": {
#     "admin2": "Adraskan",
#     "admin1": "Herat",
#     "country": "Afghanistan"
#   },
#   "Ahmadaba  Afghanistan": {
#     "admin2": "Kohsan",
#     "admin1": "Herat",
#     "country": "Afghanistan"
#   },
#   "Ajrestaan  Afghanistan": {
#     "admin2": "Ajristan",
#     "admin1": "Ghazni",
#     "country": "Afghanistan"
#   },
#   "Alasay  Afghanistan": {
#     "admin2": "Alasay",
#     "admin1": "Kapisa",
#     "country": "Afghanistan"
#   },
#   "Aleengar  Afghanistan": {
#     "admin2": "Alingar",
#     "admin1": "Laghman",
#     "country": "Afghanistan"
#   },
#   "Aliabad  Afghanistan": {
#     "admin2": "Chahar Dara",
#     "admin1": "Kunduz",
#     "country": "Afghanistan"
#   },
#   "AliSheng  Afghanistan": {
#     "admin2": "Alishing",
#     "admin1": "Laghman",
#     "country": "Afghanistan"
#   },
#   "Almaar  Afghanistan": {
#     "admin2": "",
#     "admin1": "",
#     "country": ""
#   },
#   "Anaar Darah  Afghanistan": {
#     "admin2": "Anar Dara",
#     "admin1": "Farah",
#     "country": "Afghanistan"
#   },
#   "Andar  Afghanistan": {
#     "admin2": "Andar",
#     "admin1": "Ghazni",
#     "country": "Afghanistan"
#   },
#   "Andaraab  Afghanistan": {
#     "admin2": "Andarab",
#     "admin1": "Baghlan",
#     "country": "Afghanistan"
#   },
#   "Andkhoy  Afghanistan": {
#     "admin2": "Khani Chahar Bagh",
#     "admin1": "Faryab",
#     "country": "Afghanistan"
#   },
#   "Arghandaab  Afghanistan": {
#     "admin2": "Arghandab",
#     "admin1": "Kandahar",
#     "country": "Afghanistan"
#   },
#   "Arghandab  Afghanistan": {
#     "admin2": "Arghandab",
#     "admin1": "Kandahar",
#     "country": "Afghanistan"
#   },
#   "Arghestaan  Afghanistan": {
#     "admin2": "Arghistan",
#     "admin1": "Kandahar",
#     "country": "Afghanistan"
#   },
#   "Asadabad  Afghanistan": {
#     "admin2": "",
#     "admin1": "Kunar",
#     "country": "Afghanistan"
#   }
# }

# %%
# !rm ../data/interim/geo_query_cache.json
